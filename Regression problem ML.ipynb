# %% [markdown]
# # X = Independent variable
# # Y = Dependent variable (Continouse number)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("weight-height.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  10000 non-null  object
#  1   Height  10000 non-null  float64
#  2   Weight  10000 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 234.5+ KB

# %%
df.describe()
# Out:
#              Height        Weight
# count  10000.000000  10000.000000
# mean      66.367560    161.440357
# std        3.847528     32.108439
# min       54.263133     64.700127
# 25%       63.505620    135.818051
# 50%       66.318070    161.212928
# 75%       69.174262    187.169525
# max       78.998742    269.989699

# %%
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
df.Height.values
# Out:
# array([73.84701702, 68.78190405, 74.11010539, ..., 63.86799221,
#        69.03424313, 61.94424588])

# %%
df.Weight.values
# Out:
# array([241.89356318, 162.31047252, 212.74085556, ..., 128.47531878,
#        163.85246135, 113.64910268])

# %%
X = df.Height.values
Y = df.Weight.values

print(len(X))
print(len(Y))
# Out:
# 10000
# 10000

# %%
print(X[0])
print(Y[0])
# Out:
# 73.847017017515
# 241.893563180437

# %%
plt.scatter(X,Y)

# %% [markdown]
# # line function

# %% [markdown]
# Y = wx + b
#
# findw,b

# %%
def line(x, w, b=0):
    return w*x +b

# %% [markdown]
# # Loss function

# %%
def mean_sqaured_error(y_true, y_pred):
    s = (y_true - y_pred) **2
    return np.sqrt(s.mean())

# %%
plt.figure(figsize=(10,5))
ax1 = plt.subplot(121)
df.plot(kind= "scatter",
       x= "Height",
       y= "Weight",
       title= "Weight and Height in Adults",
       ax=ax1)
plt.show()

# %%
plt.figure(figsize=(10,5))
ax1 = plt.subplot(121)
df.plot(kind= "scatter",
       x= "Height",
       y= "Weight",
       title= "Weight and Height in Adults",
       ax=ax1)

bs = [-100,-50,100,0,50,100,150]
mses = []
for b in bs:
        y_pred = line(X , 2 ,b)
        mse = mean_sqaured_error(Y, y_pred)
        mses.append(mse)
        plt.plot(X, y_pred)

# %%
plt.figure(figsize=(10,5))
ax1 = plt.subplot(121)
df.plot(kind= "scatter",
       x= "Height",
       y= "Weight",
       title= "Weight and Height in Adults",
       ax=ax1)

bs = [-100,-50,0,50,100,150]
mses = []
for b in bs:
        y_pred = line(X , 2 ,b)
        mse = mean_sqaured_error(Y, y_pred)
        mses.append(mse)
        plt.plot(X, y_pred)
        
ax2 = plt.subplot(122)
ax2.plot(bs,mses,"o-")
plt.title("Cost as funtion of b")
plt.xlabel("B")
# Out:
# Text(0.5, 0, 'B')

# %%
plt.figure(figsize=(10,5))
ax1 = plt.subplot(121)
df.plot(kind= "scatter",
       x= "Height",
       y= "Weight",
       title= "Weight and Height in Adults",
       ax=ax1)

bs = [50]
mses = []
for b in bs:
        y_pred = line(X , 2 ,b)
        mse = mean_sqaured_error(Y, y_pred)
        mses.append(mse)
        plt.plot(X, y_pred, "r")
        
# ax2 = plt.subplot(122)
# ax2.plot(bs,mses,"o-")
# plt.title("Cost as funtion of b")
# plt.xlabel("B")
# plt.show()

# %%
plt.figure(figsize=(10,5))
ax1 = plt.subplot(121)
df.plot(kind='scatter',
      x='Height',
      y='Weight',
      title="Weight and Height in Adults",
      ax=ax1)


y_pred = line(X,7.6609,-348.16)# i passed machine learning trained parameters
plt.plot(X,y_pred,'r')
#     break
